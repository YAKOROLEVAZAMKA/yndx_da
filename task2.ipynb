# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Сергей, привет!👋</b>
#
# Меня зовут Арина Уксусова, я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. Это нужно, чтобы не создавалась путаница😉
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
#
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b> В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Правильно подгружать все необходимые библиотеки в самой верхней части кода, но все-таки лучше это делать после введения в проект. Важно соблюдать некую логику при построении структуры проекта и добиваться его презентабельности, ведь конечный потребитель твоего анализа - это заказчик, которому ты будешь презентовать проект.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Уважаемая Арина, доброе утро! <br>
#
# Действительно, согласно PEP-8 Вы абсолютно правы: <br>
# "Импорты всегда помещаются в начале файла, сразу после комментариев к модулю и строк документации, и перед объявлением констант." <br>
#
# Касательно презентабельности - если проект нужно показывать заказчику то разумеется я не буду показывать всю тетрадку, я просто оберну весь код в класс:<br>
#
#     class AnalyseRealEstate(...):
#
#         def __init__(self, ...):
#             ...
#
# После чего положу в AnalyseRealEstate.py и сделаю импорт <b>from AnalyseRealEstate.py import AnalyseRealEstate(...)</b><br>
#
# В результате заказчик увидит промежуточные результаты + финальный вывод, на сам код внутри проекта заказчику смотреть в принципе не нужно. Бизнесу нужны выводы и визуализация, а не код, в котором он не обязан разбираться.
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Снова небольшая ремарка по оформлению. Хорошо, что ты начинаешь работу с короткого введения, но этого недостаточно! Твое intro может выглядеть еще лучше и информативнее, если использовать не только готовый шаблон из описания проекта, но и составлять план, в котором можно и нужно зафиксировать основную цель проекта, этапы или шаги проекта; план можно оформить с помощью гиперссылок в ячейках Markdown. Обязательно попробуй такой подход в своих будущих проектах, это улучшит восприятие проекта внешними наблюдателями, в том числе заказчиками, упростит навигацию по твоей работе.
# <a href="https://coderoad.ru/11948245/Markdown-для-создания-страниц-и-оглавления" title="Markdown оформление оглавления">По этой ссылке</a> ты сможешь найти информацию о том, как оформить проект, добавив к нему оглавление с гиперссылками на отдельные части!😎
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Короткое введение - это стандартное введение, я ничего не писал))
#
# Как я уже писал выше - не вижу смысла подробно расписывать все шаги по пунктам в начале проекта, тем более что они описаны в самом конце. Возможно имеет смысл перенести чек-лист из конца в начало?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Сергей, введение в проект - важная часть оформления тетрадки с кодом. Предложение по разделение кода и выводов - адекватное, но пока у нас есть только возможность работать в таком формате (формат Jupyter Notebook, который позволяет фиксировать и код, и комментарии) нужно попытаться оформлять проект, исходя из возможностей IDE и рекомендаций Яндекс.Практикума. Здесь имеется в виду не чек-лист (чек-лист - это, скорее, ориентир для студента), а подход как к презентации, где ты фиксируешь СЛОВАМИ цель проекта, основные задачи (не обязательно под копирку брать названия шагов из инструкции к проекту, здесь есть возможности для лавирования, главное, сохранить общий смысл и канву), даешь краткое вводное в тематику проекта.
# </div>

# %% [markdown]
# ### Шаг 1. Откройте файл с данными и изучите общую информацию.

# %%
data: pd.DataFrame = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
data.describe()
# Out:
#        total_images     last_price  total_area     rooms  ceiling_height  \
# count     23,699.00      23,699.00   23,699.00 23,699.00       14,504.00
# mean           9.86   6,541,548.77       60.35      2.07            2.77
# std            5.68  10,887,013.27       35.65      1.08            1.26
# min            0.00      12,190.00       12.00      0.00            1.00
# 25%            6.00   3,400,000.00       40.00      1.00            2.52
# 50%            9.00   4,650,000.00       52.00      2.00            2.65
# 75%           14.00   6,800,000.00       69.90      3.00            2.80
# max           50.00 763,000,000.00      900.00     19.00          100.00
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count     23,613.00    21,796.00 23,699.00     21,421.00 12,180.00
# mean          10.67        34.46      5.89         10.57      1.15
# std            6.60        22.03      4.89          5.91      1.07
# ...

# %%
data.head()
# Out:
#    total_images    last_price  total_area first_day_exposition  rooms  \
# 0            20 13,000,000.00      108.00  2019-03-07T00:00:00      3
# 1             7  3,350,000.00       40.40  2018-12-04T00:00:00      1
# 2            10  5,196,000.00       56.00  2015-08-20T00:00:00      2
# 3             0 64,900,000.00      159.00  2015-07-24T00:00:00      3
# 4             2 10,000,000.00      100.00  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70         16.00        51.00      8          NaN   False
# 1             nan         11.00        18.60      1          NaN   False
# 2             nan          5.00        34.30      4          NaN   False
# 3             nan         14.00          nan      9          NaN   False
# 4            3.03         14.00        32.00     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data.duplicated().sum()
# предварительно полных дублей данных нет
# Out:
# 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Судя по методу info() в исходных данных очень много пропусков, типы данных не соответствуют реальным (например число балконов не целочисленное число, а с плавающей точкой), названия столбцов (а так же их порядок) оставляют желать лучшего.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍:</b> Тебе удалось обнаружить проблемы с типами данных и с пропусками! Хорошая работа!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Ок, а что ты можешь сказать по поводу аномалий в данных? Есть ли выбросы? Такие значения тоже важно обнаружить сразу, еще на первых этапах анализа, поскольку они могут оказать влияние на итоговый результат исследования.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# В начале я анализирую корректность предоставленных данных. Анализировать аномалии имеет смысл только если конкретные данные в принципе нужны - например я мог бы найти аномалии и выбросы в столбце <b>'total_images'</b>, но этот столбец в принципе не нужен\не пригодился в анализе, поэтому я считаю что решать проблемы выбросов и аномалий нужно по мере их поступления, а не тратить на это время в самом начале.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Думаю, ты согласишься с мнением, что аномалии надо выделять, например, до построения корреляции, например. Насколько это "по мере поступления" - конечно, решать аналитику, тут важно его экспертное мнение!
# </div>

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %%
list(data.columns)
# Out:
# ['total_images',
#  'last_price',
#  'total_area',
#  'first_day_exposition',
#  'rooms',
#  'ceiling_height',
#  'floors_total',
#  'living_area',
#  'floor',
#  'is_apartment',
#  'studio',
#  'open_plan',
#  'kitchen_area',
#  'balcony',
#  'locality_name',
#  'airports_nearest',
#  'cityCenters_nearest',
#  'parks_around3000',
#  'parks_nearest',
#  'ponds_around3000',
#  'ponds_nearest',
#  'days_exposition']

# %%
# Переименуем столбы
data.rename(columns={
                        'total_area': 'total_area_m2',
                        'last_price': 'price',
                        'rooms': 'rooms_amount',
                        'ceiling_height': 'ceiling_height_m',
                        'living_area': 'living_area_m2',
                        'studio': 'is_studio',
                        'open_plan': 'is_open_plan',
                        'kitchen_area': 'kitchen_area_m2',
                        'balcony': 'balcony_amount',
                        'locality_name': 'city_name',
                        'airports_nearest': 'airport_distance_m',
                        'cityCenters_nearest': 'city_center_distance_m',
                        'parks_around3000': 'parks_amount_within_3km',
                        'parks_nearest': 'nearest_park_distance_m',
                        'ponds_around3000': 'ponds_amount_within_3km',
                        'ponds_nearest': 'nearest_pond_distance_m'
            }, inplace=True)

data = data[['city_name',
             'total_images',
             'first_day_exposition',
             'days_exposition',
             'price',
             'floors_total',
             'floor',
             'is_apartment',
             'is_studio',
             'total_area_m2',
             'living_area_m2',
             'kitchen_area_m2',
             'rooms_amount',
             'balcony_amount',
             'ceiling_height_m',
             'is_open_plan',
             'airport_distance_m',
             'city_center_distance_m',
             'parks_amount_within_3km',
             'nearest_park_distance_m',
             'ponds_amount_within_3km',
             'nearest_pond_distance_m'
            ]]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍:</b> Ты использовал верный метод для переименования столбцов, отлично!
# </div>

# %%
data.head()
# Out:
#          city_name  total_images first_day_exposition  days_exposition  \
# 0  Санкт-Петербург            20  2019-03-07T00:00:00              nan
# 1   посёлок Шушары             7  2018-12-04T00:00:00            81.00
# 2  Санкт-Петербург            10  2015-08-20T00:00:00           558.00
# 3  Санкт-Петербург             0  2015-07-24T00:00:00           424.00
# 4  Санкт-Петербург             2  2018-06-19T00:00:00           121.00
#
#           price  floors_total  floor is_apartment  is_studio  total_area_m2  \
# 0 13,000,000.00         16.00      8          NaN      False         108.00
# 1  3,350,000.00         11.00      1          NaN      False          40.40
# 2  5,196,000.00          5.00      4          NaN      False          56.00
# 3 64,900,000.00         14.00      9          NaN      False         159.00
# 4 10,000,000.00         14.00     13          NaN      False         100.00
#
#    living_area_m2  kitchen_area_m2  rooms_amount  balcony_amount  \
# ...

# %%
print(f'Количество различных населенных пунктов - {len(data.city_name.unique())}')
print(f'Количество пропусков в населенных пунктах - {data.city_name.isna().sum()}')
data = data[~data['city_name'].isna()].reset_index(drop=True)

data.city_name = data.city_name.apply(lambda x: x.lower().strip().replace('ё', 'е'))
print(f'Количество различных населенных пунктов после стандартизации - {len(data.city_name.unique())}')
print(f'Количество полных дублей - {data.duplicated().sum()}')
# Out:
# Количество различных населенных пунктов - 365
# Количество пропусков в населенных пунктах - 49
# Количество различных населенных пунктов после стандартизации - 330
# Количество полных дублей - 0

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Ты получил конкретный результат по итогу использования некоторого кода. Но что значит этот результат? Для чего ты предпринял эти действия? Очень важно не только представлять кодовое решение задачи, но и сопровождать его объяснением, разъясняющими комментариями и интерпретировать результат выполнения кода. Ценность работы аналитика не стоько в умении виртуозно решать задачи с помощью кода, но и - и это даже важнее, - объяснять свои действия и интерпретировать результаты. Поскольку опять же, целевая аудитория твоей работы - непрофессионалы, которые не владеют твоим инструментарием. да, ревьюеры могут понять то, что ты хотел "сказать" этим кодом, но заказчик, скорее всего, вряд ли. Об этом важно помнить. Пожалуйста, прокомментируй свои действия здесь.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Цель действий выше - удаление дублей названий населенных пунктов, после чего можно будет делать корректные выводы о количестве объявлений в конкретном населенном пункте. Если этого не делать - то мы можем сделать впоследствии неверные выводы (в зависимости от количества дублей значений).
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Да, вполне оправданно.
# </div>

# %%
# проверка на пропуски

# is_apartment
print(data['is_apartment'].unique())

data['is_apartment'].fillna(False, inplace=True)

print(data['is_apartment'].unique())

# is_studio
print(data['is_studio'].unique())

# is_open_plan
print(data['is_open_plan'].unique())
# Out:
# [nan False True]
# [False  True]
# [False  True]
# [False  True]

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Здесь также важно оставить поясняющий комментарий к коду!👀
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Цель ячейки выше - проверка на пропуски. В апартаментах есть пропущенные значения, которые я заполнил опираясь на субъективное мнение заключающееся в том, что пропуск в данном случае - это человеческий фактор в результате которого вместо значения <b>False</b> поле не заполнялось в принципе.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍</b>
# </div>

# %%
# общее число пропусков
print(data.isnull().sum().sort_values())

# пропуски в процентном соотношении
(
    print(
        (data.isnull()
             .sum()
             .sort_values() / data.shape[0] * 100
        ).reset_index()
         .rename(columns={'index': 'metric', 0: 'percent'})
         .query('percent > 0')
    )
)
# Out:
# city_name                      0
# total_images                   0
# first_day_exposition           0
# is_open_plan                   0
# price                          0
# floor                          0
# is_apartment                   0
# is_studio                      0
# total_area_m2                  0
# rooms_amount                   0
# floors_total                  85
# living_area_m2              1898
# kitchen_area_m2             2269
# days_exposition             3180
# ponds_amount_within_3km     5510
# parks_amount_within_3km     5510
# city_center_distance_m      5511
# airport_distance_m          5534
# ceiling_height_m            9160
# balcony_amount             11513
# nearest_pond_distance_m    14565
# nearest_park_distance_m    15586
# dtype: int64
#                      metric  percent
# 10             floors_total     0.36
# 11           living_area_m2     8.03
# 12          kitchen_area_m2     9.59
# 13          days_exposition    13.45
# ...

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# - пропуски выглядят некритичными - количество этажей в доме не заполнено всего 0.36% от общей массы;
# - расстояние до ближайшего пруда\аэропорта продавцы могут банально не знать;
# - пропуски в количестве балконов наиболее вероятно означают что балкона нет;
# - высота потолка - достаточно спорный атрибут квартиры, дальнейший анализ покажет влияет ли он на что-либо
# и если влияет - то я его заполню средними значениями, если не влияет - останется как есть
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Все сопроводительные комментарии/объяснения, если их длина довольно большая, лучше выносить в отдельные ячейки Markdown.
# </div>

# %%
# преобразуем объект в дату
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format="%Y-%m-%d")

# год - месяц - день недели

data['year'] = data['first_day_exposition'].dt.year
data['month'] = data['first_day_exposition'].dt.month
data['weekday'] = data['first_day_exposition'].dt.dayofweek

# %%
# изменение типов данных + преобразование
def convert_to_int(df, arr):
    for col in arr:
        df[col] = df[col].fillna(0)
        df[col] = df[col].astype(int)
        
cols_to_int = ['days_exposition', 
               'floors_total', 
               'balcony_amount', 
               'parks_amount_within_3km', 
               'ponds_amount_within_3km']

convert_to_int(data, cols_to_int)

def change_distance(df, arr, dist=1000):
    for col in arr:
        df[col] = df[col].fillna(0)
        df[col] = round(df[col] / dist, 2)
        df.rename(columns={col: col.replace('_m', '_km')}, inplace=True)

cols_to_km = ['airport_distance_m', 
              'city_center_distance_m', 
              'nearest_park_distance_m',
              'nearest_pond_distance_m']        
        
change_distance(data, cols_to_km)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Отличная функция! Но какова цель ее написания? Какого результата с помощью нее ты хотел добиться? Пожалуйста, поясни свои действия.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> В целом инструкция, которая дана тебе как ориентир для выполнения задачи, уже содержит в себе подпункты каждого шага в проекте. Эти подпункты шага лучше также фиксировать, чтобы твой проект содержал не просто код, а представлял собой последовательный отчет.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Сейчас мы находимся здесть - <b>Шаг 2. Предобработка данных</b><br>
# В рамках этого шага конкретно в ячейке выше я занимаюсь измененим типов данных + их преобразованием.<br>
#
# Функция <b>convert_to_int</b> получает на вход 2 аргумента - <b>объект типа DataFrame</b> и <b>последовательность</b> (arr - array, хотя логичнее было бы назвать seq - sequence), после чего для каждого значения из последовательности заполняет пропуски в объекте DataFrame нулями, а затем преобразует тип данных в целочисленный.
#
# Функция <b>change_distance</b> получает на вход 3 аргумента - <b>объект типа DataFrame</b>, <b>последовательность</b> и расстояние (значение по умолчанию - 1000). Для каждого значения из последовательности в объекте DataFrame происходит заполнение пустых значений соответствующей колонки нулями, после чего все значения колонки делятся на аргумент dist (distance), в результате чего происходит преобразование расстояния из метров в километры. В самом конце колонка переименовывается (было - "xxx_m", стало - "xxx_km").
#
#
# <b>Нужна ли эта информация бизнесу? Нет.</b><br>
# Нужна ли эта информация другому человеку, который впоследствии будет работать с этими данными? Нет, т.к. это описание является <b>избыточным комментарием\описанием</b>, если человек не разбирается в функции из 4-х строк с одним циклом - это печально.
#
# Писать комментарии\описание для сложных функций нужно абсолютно точно, но таковых пока что в рамках практикума я не писал :)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Здесь имелось в виду не столько "техническое" объяснение того, как функция работает (какие аргументы принимает на вход, что преобразует во что, как меняет значения и т.д. и т.п.), а содержательный смысл твоих действий, почему эта функция написана (чтобы заполнить пропуски) и почему важно пропуски заполнить (потому что это может повлиять на результат анализа). То, что заказчику не обязательно владеть информацией о том, из ч его функция состоит, сколько циклов включает - согласна полностью. Но заказчику следует знать, какую задачу ты решаешь, почему предложенный тобой метод оправдан/адекватен/эффективен и какую ценность несет эта функция (или любое другое кодовое решение) для целей проекта.
# </div>

# %%
data.head()
# Out:
#          city_name  total_images first_day_exposition  days_exposition  \
# 0  санкт-петербург            20           2019-03-07                0
# 1   поселок шушары             7           2018-12-04               81
# 2  санкт-петербург            10           2015-08-20              558
# 3  санкт-петербург             0           2015-07-24              424
# 4  санкт-петербург             2           2018-06-19              121
#
#           price  floors_total  floor  is_apartment  is_studio  total_area_m2  \
# 0 13,000,000.00            16      8         False      False         108.00
# 1  3,350,000.00            11      1         False      False          40.40
# 2  5,196,000.00             5      4         False      False          56.00
# 3 64,900,000.00            14      9         False      False         159.00
# 4 10,000,000.00            14     13         False      False         100.00
#
#    living_area_m2  kitchen_area_m2  rooms_amount  balcony_amount  \
# ...

# %%
def floor_conv(df, fl_total, fl_current, col_name='floor_type'):
    df[col_name] = ''
    
    for i in range(df.shape[0]):
        if df[fl_current][i] == 1:
            df[col_name][i] = 'Первый'
        elif df[fl_current][i] != df[fl_total][i]:
            df[col_name][i] = 'Другое'
        else:
            df[col_name][i] = 'Последний'
        
print(f"Количество неизвестноэтажек - {len(data[data['floor'] > data['floors_total']])}")
print(f"Всего объявлений - {data.shape[0]}")
# В целом очень маленькое количество, влиять на конечный результат сильно не будет, 
# поэтому попадёт в категорию "Другие" (если уже в 1-й этаж не попали)       

floor_conv(data, 'floors_total', 'floor')
# Out:
# Количество неизвестноэтажек - 85
# Всего объявлений - 23650
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> И снова: с точки зрения продвинутости кода - это очень крутое решение, функция действительно интересна, но что она делает? Какой результат мы получаем на выходе? Постарайся расшифровать🤓
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# С точки зрения кода функция выше (<b>прошу прощения</b>) - г, такие вещи нужно уметь делать с помощью lambda-функций в одну строку.
#
# Функция <b>floor_conv</b> получает на вход 4 аргумента - <b>объект типа DataFrame</b>, название столбца с количеством всех этажей в доме,  этаж на котором находится квартира из объявления, название нового столбца со значением по умолчанию "floor_type" (тип этажа).
#
# Далее, в объекте DataFrame создаётся новый пустой столбец (с названием из 4-го аргумента), в цикле проходятся все строки из объекта DataFrame, для каждой строки в результате логической конструкции <b>if-elif-else</b> новому столбцу присваиваются соответствующие значения: <b>"Первый"</b> если текущий этаж равен 1, <b>"Последний"</b> если текущий этаж равен максимальному этажу в доме, <b>"Другое"</b> если ни одно из этих условий не выполнено.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Ну, скажем, все, что касается синтаксического сахара и возможностей/желания его применять - это дело и решение аналитика или программиста. Но любой код, если он работает и дает результат, не стоит клеймить каким-то особым образом. Но это хорошо, что ты видишь в своем решении точки для роста.
# </div>

# %%
data.head()
# Out:
#          city_name  total_images first_day_exposition  days_exposition  \
# 0  санкт-петербург            20           2019-03-07                0
# 1   поселок шушары             7           2018-12-04               81
# 2  санкт-петербург            10           2015-08-20              558
# 3  санкт-петербург             0           2015-07-24              424
# 4  санкт-петербург             2           2018-06-19              121
#
#           price  floors_total  floor  is_apartment  is_studio  total_area_m2  \
# 0 13,000,000.00            16      8         False      False         108.00
# 1  3,350,000.00            11      1         False      False          40.40
# 2  5,196,000.00             5      4         False      False          56.00
# 3 64,900,000.00            14      9         False      False         159.00
# 4 10,000,000.00            14     13         False      False         100.00
#
#    living_area_m2  kitchen_area_m2  rooms_amount  balcony_amount  \
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Ты делаешь абсолютно правильные действия, но лучше не оставлять закомментированный код в итоговой работе. Важно, чтобы любой внешний наблюдатель мог проследить твои шаги по работе с кодом. Если этот код не так важен, его можно просто удалить.🙄
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Любой внешний наблюдатель? Зачем? Бизнесу это не надо, а другой аналитик сам поймет. Возможно я ошибаюсь, но пока что моя точка зрения такова.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Хотя бы за тем, что все пишут код по-разному и используют разные методы (внутри одного языка), а иногда люди пишут на разных языках программирования! Если есть рекомендации по выполнению проекта - лучше их придерживаться.
# </div>

# %%
# рассчет цены за метр
data['meter_price'] = round(data['price'] / data['total_area_m2'], 2)

# соотношение жилой площади
data['living_area_percent'] = round(data['living_area_m2'] / data['total_area_m2'], 2)
data['kitchen_area_percent'] = round(data['kitchen_area_m2'] / data['total_area_m2'], 2)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍:</b> Верно! Очень хорошо, что ты округляешь итоговые показатели, это делает данные более аккуратными и удобными для воприятия.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b> Очень важно формулировать промежуточный вывод на каждом шаге. Пожалуйста, добавь его здесь, суммировав проделанную тобой работу и полученные результаты.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# <b>Промежуточный результат:</b>
#
# В результате предобработки данных были выполнены следующие действия:
#
# - удалены дубликаты городов;
# - переименованы столбцы;
# - часть пропущенных данных была заполнена;
# - на основе имеющихся данных были созданы следующие столбцы - год, месяц, день недели, тип этажа,
# цена за квадратный метр, соотношение площади кухни к общей площади, соотношение жилой площади к общей площади
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍</b>
# </div>

# %% [markdown]
# ### Шаг 3. Изучение данных

# %%
data.corr()['ceiling_height_m'].reset_index().rename(columns={'index': 'metric'}).sort_values(by='ceiling_height_m')
# Out:
#                       metric  ceiling_height_m
# 15   city_center_distance_km             -0.05
# 3               floors_total             -0.03
# 20                      year             -0.01
# 4                      floor             -0.01
# 22                   weekday             -0.01
# 0               total_images             -0.00
# 21                     month             -0.00
# 6                  is_studio              0.00
# 14       airport_distance_km              0.00
# 19  nearest_pond_distance_km              0.01
# 1            days_exposition              0.01
# 24       living_area_percent              0.01
# 25      kitchen_area_percent              0.02
# 11            balcony_amount              0.03
# 17  nearest_park_distance_km              0.03
# 13              is_open_plan              0.04
# 10              rooms_amount              0.05
# 16   parks_amount_within_3km              0.06
# 18   ponds_amount_within_3km              0.07
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b> Недостаточно просто использовать корреляцию, важно интерпретировать полученный результат. Корреляция слишком важный статистический метод, чтобы оставлять его без внимания и объяснения!🙄
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# <b>Промежуточный результат:</b>
#
# С помощью метода corr() были получены значения корреляции для высоты потолков. Из них следует что высота потолка <b>не зависит</b> от каких-либо факторов - площади квартиры, цены, расстояния до центра города и т.д.
#
# Графики для высоты потолка присутствуют далее.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Корректная интерпретация, все получилось.
# </div>

# %%
data[['total_area_m2', 'price', 'rooms_amount', 'ceiling_height_m']].describe()
# Out:
#        total_area_m2          price  rooms_amount  ceiling_height_m
# count      23,650.00      23,650.00     23,650.00         14,490.00
# mean           60.33   6,541,126.90          2.07              2.77
# std            35.66  10,896,399.18          1.08              1.26
# min            12.00      12,190.00          0.00              1.00
# 25%            40.00   3,400,000.00          1.00              2.52
# 50%            52.00   4,650,000.00          2.00              2.65
# 75%            69.70   6,799,000.00          3.00              2.80
# max           900.00 763,000,000.00         19.00            100.00

# %%
# все-таки высота потолков важна, наиболее разумным решением мне кажется заполнить её
# медианным значением ибо выборка большая, адекватных данных много, а зависимость высоты
# от чего-либо не наблюдается 
data['ceiling_height_m'].fillna(data['ceiling_height_m'].median(), inplace=True)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> На самом деле существуют также статистические аргументы в пользу использования той или иной статистики для заполнения пропущенных значений. Они тебе известны? Постарайся вспомнить, какими качествами с точки зрения статистики должны отличаться данными, чтобы применение медианы для заполнения пропущенных значений было адекватным. Спойлер: стоит посмотреть на распределение (например, построив гистограмму) и на выбросы.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# <b>Промежуточный результат:</b>
#
# Исходя из того, что высота потолка <b>напрямую не зависит</b> от каких-либо внешних факторов (в каком-нибудь посёлке городского типа это может быть современный коттеджный поселок с потолками 4+ метра, в то время как в центре Санкт-Петербурга это может быть старая хрущёвка) мне показалось наиболее логичным заполнить её медианным (либо средним) значением. А вообще по-хорошему её не нужно было заполнять в принципе, т.к. это величина абсолютно рандомная. Вот если бы в данных был тип дома - сталинка\хрущевка и т.д. и т.п. тогда был бы другой разговор.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Очень конкретное, логичное и последовательное объяснение, отличная работа!
# </div>

# %%
data['price_mil'] = data['price'] / 1000000

# %%
key_cols = ['total_area_m2', 'price', 'rooms_amount', 'ceiling_height_m']

# %%
data[key_cols].describe()
# Out:
#        total_area_m2          price  rooms_amount  ceiling_height_m
# count      23,650.00      23,650.00     23,650.00         23,650.00
# mean           60.33   6,541,126.90          2.07              2.72
# std            35.66  10,896,399.18          1.08              0.99
# min            12.00      12,190.00          0.00              1.00
# 25%            40.00   3,400,000.00          1.00              2.60
# 50%            52.00   4,650,000.00          2.00              2.65
# 75%            69.70   6,799,000.00          3.00              2.70
# max           900.00 763,000,000.00         19.00            100.00

# %%
ax = data[key_cols].plot(kind='box', subplots=True, layout=(2,2), figsize=(20,8), 
                         title='Гистограммы параметров')

ax.titlesize = '30'
plt.rcParams['font.size'] = '16'


ylims = [100, 10000000, 5, 4]
labels = ['График общей площади квартиры', 'График цены', 'Количество комнат', 'Высота потолков']

for i in range(len(key_cols)):
    ax[key_cols[i]].set_title(labels[i])
    ax[key_cols[i]].set(xticklabels=[])
    ax[key_cols[i]].set_ylim(0, ylims[i])

# %% [markdown]
# Изучаем данные:
#
# Медианная площадь ~50 кв.м, квартили - 40 и 70. <br>
# Средняя цена - от 3.8 млн до 6,5 за квартиру. <br>
# Количество комнат - 1-3, 0 комнат (студии) встречается редко как и большее количество комнат (4 и более). <br>
# Высота потолков - примерно 2,7 м.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Да, тебе удалось верно зафиксировать значения статистических показателей. Но что значат эти цифры в контексте темы нашего исследования? Как бы ты мог связать конкретные цифры с общим содержательным контекстом исследования? Важно понимать, что заказчик навряд ли ждет, что ты просто скажешь ему значение медианы. Здесь следует дополнить язык "статистики", языком "бизнеса", "перевести" полученные тобой результаты на язык, понятный закзачику, ведь ценность в интерпретации.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# <b>Промежуточный результат:</b>
#
# Для бизнеса есть заключение в конце. Помежуточные результаты бизнес не волнуют :) Эти графики - для меня, а не для бизнеса :)
#
# Что означают эти данные? Мы нашли самые распространенные предложения на рынке:
#
# - Медианная площадь ~50 кв.м, квартили - 40 и 70.
# - Средняя цена - от 3.8 млн до 6,5 за квартиру.
# - Количество комнат - 1-3, 0 комнат (студии) встречается редко как и большее количество комнат (4 и более).
# - Высота потолков - примерно 2,7 м.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b> Лучше уделить больше внимания оформлению графиков: следует добавлять названия осей и общий заголовки на русском языке. Постарайся исправить этот момент для всех графиков твоего проекта!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b> Здесь не хватает промежуточного вывода по итогу анализа на шаге 3. Добавь его, пожалуйста!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Сергей, бизнес волнует все! Но если даже предположить, что ты прав, в любом случае есть рекомендации Яндекс.Практикума, которые советуют-таки формулировать промежуточные выводы. Здесь в Яндекс.Практикуме мы пытаемчя помимо того, что научить вас техническим скиллам, мы бы очень хотели научить вас думать и анализировать, формулировать свои мысли и доносить их до неспециалистов.
# </div>

# %% [markdown]
# ### Шаг 4. Проведите исследовательский анализ данных и выполните инструкции:

# %%
bxplt1 = data.boxplot('days_exposition', 
                      figsize=(5,10)).set(xticklabels=[]) 
plt.title('Количество дней продаж')
# видим много выбросов
# Out:
# Text(0.5, 1.0, 'Количество дней продаж')

# %%
bxplt2 = data.query('5 < days_exposition < 600').boxplot('days_exposition', figsize=(5,10)).set(xticklabels=[]) 
plt.title('Количество дней продаж с фильтром')
# Out:
# Text(0.5, 1.0, 'Количество дней продаж с фильтром')

# %% [markdown]
# По поводу времени продажи:
#
# 1) Медианное значение - 3 месяца (95 дней +-) <br>
# 2) Квартиры редко продаются менее чем за 50 дней <br>
# 3) В основном квартиры продаются в срок от 50 до 200 дней <br>
# 4) Продажа квартир в срок более чем 430 дней - выброс

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Не констатируй, а интерпретируй!😉
# </div>

# %%
data_clean = data.query("\
                          20 < total_area_m2 < 100 and\
                          2 < price_mil < 10 and\
                          2.3 < ceiling_height_m < 3 and\
                          5 < days_exposition < 600\
").copy().reset_index(drop=True)

# %%
def table_metrics(df, df_clean, metric_arr, func='median'):
    df_final = None
    
    for metric in metric_arr:
        if df_final is None:
            df_final = pd.DataFrame(zip([metric], 
                                        [df[metric].agg(func=func)], 
                                        [df_clean[metric].agg(func=func)]),
                                   columns=['Метрика', 'С выбросами', 'Без выбросов']
                                   )
        else:
            df_temp = pd.DataFrame(zip([metric], 
                                       [df[metric].agg(func=func)], 
                                       [df_clean[metric].agg(func=func)]),
                                   columns=['Метрика', 'С выбросами', 'Без выбросов']
                                   ).reset_index(drop=True)
            df_final = pd.concat([df_final, df_temp])
    
    return df_final

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Интересная функция! Наверно, очень эффективная! Твой продвинутый код приобретет большую ценность, если ты постараешься объяснить, зачем ты его пишешь и какую цель преследуешь, используя такой сложный алгоритм решения.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Данная функция принимает на вход очищенные и неочищенные исходные данные, интересующие нас метрики и аггрегирующую функцию. В результате мы получаем сводную таблицу метрик по очищенным\неочищенным данным. Функция по умолчанию - вычисление медианного значения. Далее я так же использую функцию среднего значения.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍</b>
# </div>

# %%
table_metrics(data, data_clean, key_cols)
# Out:
#             Метрика  С выбросами  Без выбросов
# 0     total_area_m2        52.00         47.00
# 0             price 4,650,000.00  4,300,000.00
# 0      rooms_amount         2.00          2.00
# 0  ceiling_height_m         2.65          2.65

# %%
table_metrics(data, data_clean, key_cols, 'mean')
# Out:
#             Метрика  С выбросами  Без выбросов
# 0     total_area_m2        60.33         50.56
# 0             price 6,541,126.90  4,635,713.59
# 0      rooms_amount         2.07          1.84
# 0  ceiling_height_m         2.72          2.63

# %% [markdown]
# После обработки выбросов данные изменились следующим образом:
#
# Медианная площадь продаваемых квартир уменьшилась с 52 до 47 метров (а 10%), а средняя - с 60 до 50 (на 20%). <br>
# Медианная цена квартир изменилась на 7% - с 4,65 млн до 4,3 млн, в то время как средняя аж на 41% - с 6,5 млн опустилась до 4,6. <br>
# Количество комнат (2) и высота потолков (2.65 м) практически не отличаются.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Хорошо, это ясно, но в чем ценность этих изменений для исследования? Почему выбросы было необходимо удалить из датасета? Попробуй объяснить!
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Выбросы необходимо удалять из датасета для того, чтобы в результате получить корректные итоговые данные. Не "среднее по больнице", не "бедные едят капусту, богатые едят мясо, в среднем все едят голубцы".
#
# Имея выброс в виде нескольких квартир с ценой в несколько миллиардов (или с высотой потолка в миллионы километров) все средние значения потеряли бы свой смысл.
#
# Весь итоговый анализ должен проводиться на очищенных данных.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Да, все верно!
# </div>

# %%
cm = sns.light_palette("green", as_cmap=True)

data[['meter_price',\
           'total_area_m2',\
           'price',\
           'days_exposition',\
           'city_center_distance_km',\
           'rooms_amount']].corr()['price'].reset_index().rename(columns={'index':'metric'})\
                                           .sort_values(by='price', ascending=False).reset_index(drop=True)\
                                           .drop(0).reset_index(drop=True)\
                                           .style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_a611397a_1916_11eb_b4fe_02420a390569row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_a611397a_1916_11eb_b4fe_02420a390569row1_col1 {
#             background-color:  #178d17;
#             color:  #000000;
#         }    #T_a611397a_1916_11eb_b4fe_02420a390569row2_col1 {
#             background-color:  #6dbc6d;
#             color:  #000000;
#         }    #T_a611397a_1916_11eb_b4fe_02420a390569row3_col1 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_a611397a_1916_11eb_b4fe_02420a390569row4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_a611397a_1916_11eb_b4fe_02420a390569" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >metric</th>        <th class="col_heading level0 col1" >price</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
data_clean[['meter_price',\
           'total_area_m2',\
           'price',\
           'days_exposition',\
           'city_center_distance_km',\
           'rooms_amount']].corr()['price'].reset_index().rename(columns={'index':'metric'})\
                                           .sort_values(by='price', ascending=False).reset_index(drop=True)\
                                           .drop(0).reset_index(drop=True)\
                                           .style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_a78dd57e_1916_11eb_b4fe_02420a390569row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_a78dd57e_1916_11eb_b4fe_02420a390569row1_col1 {
#             background-color:  #399f39;
#             color:  #000000;
#         }    #T_a78dd57e_1916_11eb_b4fe_02420a390569row2_col1 {
#             background-color:  #57b057;
#             color:  #000000;
#         }    #T_a78dd57e_1916_11eb_b4fe_02420a390569row3_col1 {
#             background-color:  #ddfbdd;
#             color:  #000000;
#         }    #T_a78dd57e_1916_11eb_b4fe_02420a390569row4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_a78dd57e_1916_11eb_b4fe_02420a390569" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >metric</th>        <th class="col_heading level0 col1" >price</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# Сильнее всего на стоимость квартиры влияют цена за метр квадратный (внезапно!) и общая площадь\количество комнат). <br>
# От расстояния до центра города \ количества дней продажи цена не зависит.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Вывод про связь между стоимостью квартиры и ценой за квадратный метр верен, но почему тебе показалась нелогичной эта связь? Постарайся, пожалуйста, объяснить!
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Это был сарказм.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера: вторая итерация ревью</h2>
#
# <b>Все отлично!👍:</b> Прошу прощения, что не уловила его! В любом случае, лучше придерживаться нейтрального языка при формулировании выводов/комментариев в ходе проекта.
# </div>

# %%
plt.figure(figsize=(25,25))
sns.heatmap(data.corr(), annot=True, cmap="Greens", fmt='.2f')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера</h2>
#
# <b>На доработку🤔:</b> Остальные выводы не совсем корректны: попробуй еще раз перепроверить влияние на стоимость квартиры таких факторов, как расстояние до центра и высота потолков. Особенно расстояние до центра. Тебе не кажется, что это просто даже с точки зрения здравого смысла и реальности, в которой мы живем, не совсем правильный вывод, что цена никак не связана с удаленностью от центра? Важно понимать, что не стоит 100%-но полагаться на цифры, всегда нужно верифицировать полученный результат, анализируя его с точки зрения экспертного знания о предметной области, логики и здравого смысла.
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Вывод по данным абсолютно правильный - <b>в общей массе</b> (без какой-либо конкретизирующей выборки) цена на квартиру <b>не зависит</b> от высоты потолка или удалённости от центра.
#
# <b>В конкретных выборках</b> (например в конце, выборка для центра Санкт-Петербурга) зависимость есть, в общей выборке - её нет.
#
# С точки зрения здравого смысла - в тех населенных пунктах, которые предоставлены в исходных данных, расстояние до центра (кроме Санкт-Петербурга) на 99% не имеет значения, т.к. люди либо ездят работать в Санкт-Петербург либо в центре находится ж\д станция (Парголово, Пушкин, Гатчина, Красное село и тд) и делать там (кроме как уехать) ровным счётом абсолютно нечего. Вот если бы были колонки "время до Санкт-Петербурга пешком", "Время до Санкт-Петербурга на машине", "Время до Санкт-Петербурга на общественном транспорте" - они бы играли роль в выборе квартиры =/
#
# </div>

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 12)) # create 2x2 array of subplots


bxplt0_0 = data_clean.boxplot(column='price', by='year', ax=axes[0,0]) # add boxplot to 1st subplot
bxplt0_0.set(xlabel='')
bxplt0_0.set(ylabel='Очищенные данные')
bxplt0_0.set(title='в разрезе по годам')

bxplt0_1 = data_clean.boxplot(column='price', by='month', ax=axes[0,1]) # add boxplot to 2nd subplot
bxplt0_1.set(xlabel='')
bxplt0_1.set(title='в разрезе по месяцам')

bxplt0_2 = data_clean.boxplot(column='price', by='weekday', ax=axes[0,2]) # add boxplot to 2nd subplot
bxplt0_2.set(xlabel='')
bxplt0_2.set(title='в разрезе по дням недели')
#
#
bxplt1_0 = data_clean.boxplot(column='meter_price', by='year', ax=axes[1,0]) # add boxplot to 1st subplot
bxplt1_0.set(xlabel='')
bxplt1_0.set(ylabel='Сырые данные')
bxplt1_0.set(title='в разрезе по годам')

bxplt1_1 = data_clean.boxplot(column='meter_price', by='month', ax=axes[1,1]) # add boxplot to 2nd subplot
bxplt1_1.set(xlabel='')
bxplt1_1.set(title='в разрезе по месяцам')

bxplt1_2 = data_clean.boxplot(column='meter_price', by='weekday', ax=axes[1,2]) # add boxplot to 2nd subplot
bxplt1_2.set(xlabel='')
bxplt1_2.set(title='в разрезе по дням недели')
# etc.
fig.suptitle('Гистограмы зависимости цены квартиры от времени', fontsize=26)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Показательные графики! Но стоит добавить общий заголовок и названия осей на русском языке.
# </div>

# %%
# ищем выбросы
for i in range(2014, 2020):
    
    t = data.query(f'year == {i}').shape[0]
    print(f"Квартир в {i} году - {t}")
# Out:
# Квартир в 2014 году - 136
# Квартир в 2015 году - 1173
# Квартир в 2016 году - 2765
# Квартир в 2017 году - 8185
# Квартир в 2018 году - 8512
# Квартир в 2019 году - 2879

# %% [markdown]
# Промежуточный вывод:
#
# За 2014 год данных очень мало, поэтому медианная цена (и квартили) отличается (но не очень сильно) от других лет. <br>
# День недели\месяц на цену квартиры никак не влияют. <br>
# В 2019 году цены на квартиры слегка подросли. <br>

# %%
bxfloor = data_clean.boxplot('meter_price', by='floor_type',figsize=(10,10)).set_ylim(0,170000)
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# Промежуточный вывод:
#
# Самые дешевые квартиры - на 1-ом этаже, на последнем чуть дороже, самые дорогие квартиры - не первый и не последний этажи.

# %%
data_top10 = (data_clean['city_name'].value_counts() / data.shape[0] * 100).head(10)\
                                     .reset_index().rename(columns={'index': 'city_name',
                                                                    'city_name': 'quantity'})

data_top10_price = data_clean.query('city_name in @data_top10.city_name.unique()')\
                                                          .groupby(['city_name'])[['meter_price']]\
                                                          .median()\
                                                          .reset_index()\
                                                          .rename(columns={'meter_price': 'avg_meter_price'})\
                                                          .sort_values(by='avg_meter_price', ascending=False)\
                                                          .reset_index().rename(columns={'index': 'place'})

# %%
data_merged = data_top10.merge(data_top10_price, left_on=['city_name'], right_on=['city_name'])
data_merged['place'] = abs(data_merged['place'] - 10)
data_merged = data_merged[['city_name', 'quantity', 'avg_meter_price', 'place']]

# %%
data_merged
# Out:
#            city_name  quantity  avg_meter_price  place
# 0    санкт-петербург     40.96       100,000.00      1
# 1     поселок мурино      2.09        86,231.88      5
# 2     поселок шушары      1.58        76,573.51      3
# 3         всеволожск      1.20        65,789.47     10
# 4  поселок парголово      1.18        91,428.57      4
# 5            колпино      1.15        73,913.04      7
# 6    деревня кудрово      1.12        91,734.98      8
# 7             пушкин      0.99        97,178.68      2
# 8            гатчина      0.89        67,860.57      9
# 9           петергоф      0.64        80,905.24      6

# %% [markdown]
# Промужеточный вывод:
#
# Топ-5 по количеству объявлений: <br> <br>
# 1) Санкт-Петербург <br>
# 2) Поселок Мурино <br>
# 3) Поселок Шушары <br>
# 4) Всеволожск <br>
# 5) Паселок Парголово <br>
#  <br>
# Топ-3 по цене: <br> <br>
# 1) Санкт-Петербург <br>
# 2) Пушкин <br>
# 3) Поселок Шушары <br>
# 4) Паселок Парголово <br>
# 5) Поселок Мурино <br>
#
# Наибольшее количество объявлений о продаже - в Питере и пригороде, а заодно и цена там самая высокая.
# Интересным вариантом для приобритение жилья выглядит Всеволожск - предложений много, а цена - самая низкая (!)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍:</b> Верное решение, так держать!
# </div>

# %% [markdown]
# ## Saint-Petersburg

# %%
data_spb = data_clean[data_clean['city_name'] == 'санкт-петербург'].reset_index(drop=True).copy()
data_spb['city_center_distance_km'].isna().sum()

# отлично - все значения заполнены
# Out:
# 0

# %%
data_spb['city_center_distance_km'] = data_spb['city_center_distance_km'].apply(np.ceil)
print(data_spb.query('city_center_distance_km == 0')['city_center_distance_km'].count())

# 13 выбросов - удаляем

data_spb = data_spb.query('city_center_distance_km > 0').copy()
# Out:
# 13

# %%
data_spb.groupby(['city_center_distance_km'])[['price']].mean().head(15)
# Out:
#                                price
# city_center_distance_km
# 1.00                    7,564,944.44
# 2.00                    7,498,351.32
# 3.00                    6,578,138.60
# 4.00                    6,334,260.70
# 5.00                    6,770,519.48
# 6.00                    6,629,727.62
# 7.00                    6,089,681.77
# 8.00                    6,020,154.38
# 9.00                    5,349,500.95
# 10.00                   4,857,743.24
# 11.00                   4,934,678.72
# 12.00                   5,024,342.57
# 13.00                   5,060,847.83
# 14.00                   5,217,212.45
# 15.00                   4,982,066.63

# %% [markdown]
# По сводной таблице видно что цена сильно падает на 9-ом километре - до 5-ти миллионов (с 6-7).
# Нужно ли строить график после этого? Мне кажется что нет, но построим раз в задании просят.

# %%
line_plt = data_spb.groupby(['city_center_distance_km'])[['price']].mean().head(15).plot(figsize=(15,9))

# %% [markdown]
# Собственно график подтвердил вышесказанное - 1-8 км это центр.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера</h2>
#
# <b>Некоторые замечания💡:</b> Если ты все-таки решил построить график, то лучше попытаться оформить его правильно!
# </div>

# %% [markdown]
# ## SPB Center

# %%
data_spb_center = data_clean.query('city_center_distance_km < 9')

# %%
data_spb_center[['total_area_m2',\
           'price',\
           'rooms_amount',\
           'ceiling_height_m']].corr()['price'].reset_index().rename(columns={'index':'metric'})\
                                           .sort_values(by='price', ascending=False).reset_index(drop=True)\
                                           .drop(0).reset_index(drop=True)\
                                           .style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_09b18ddc_187b_11eb_80d4_02420a39e021row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_09b18ddc_187b_11eb_80d4_02420a39e021row1_col1 {
#             background-color:  #aadeaa;
#             color:  #000000;
#         }    #T_09b18ddc_187b_11eb_80d4_02420a39e021row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_09b18ddc_187b_11eb_80d4_02420a39e021" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >metric</th>        <th class="col_heading level0 col1" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09b18ddc_187b_11eb_80d4_02420a39e021level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_09b18ddc_187b_11eb_80d4_02420a39e021row0_col0" class="data row0 col0" >total_area_m2</td>
# ...

# %% [markdown]
# Сильнее всего на цену в центре влияет площадь квартир, комнаты и потолок несущественны. Давайте посмотрим теперь вообще на все факторы!

# %%
data_spb_center.corr()['price'].reset_index().rename(columns={'index':'metric'})\
                                           .sort_values(by='price', ascending=False).reset_index(drop=True)\
                                           .drop(0).drop(1).reset_index(drop=True).head(10)\
                                           .style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_09b8695e_187b_11eb_80d4_02420a39e021row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_09b8695e_187b_11eb_80d4_02420a39e021row1_col1 {
#             background-color:  #108910;
#             color:  #f1f1f1;
#         }    #T_09b8695e_187b_11eb_80d4_02420a39e021row2_col1 {
#             background-color:  #40a340;
#             color:  #000000;
#         }    #T_09b8695e_187b_11eb_80d4_02420a39e021row3_col1 {
#             background-color:  #49a849;
#             color:  #000000;
#         }    #T_09b8695e_187b_11eb_80d4_02420a39e021row4_col1 {
#             background-color:  #6dbc6d;
#             color:  #000000;
#         }    #T_09b8695e_187b_11eb_80d4_02420a39e021row5_col1 {
#             background-color:  #87cb87;
#             color:  #000000;
#         }    #T_09b8695e_187b_11eb_80d4_02420a39e021row6_col1 {
#             background-color:  #93d193;
#             color:  #000000;
# ...

# %%
data_spb_center.boxplot('meter_price', by='floor_type',figsize=(10,10)).set_ylim(0,170000)
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# (0, 170000)

# %%
data_clean[data_clean['city_name'] == 'санкт-петербург'].corr()['price'].reset_index().rename(columns={'index':'metric'})\
                                           .sort_values(by='price', ascending=False).reset_index(drop=True)\
                                           .drop(0).drop(1).reset_index(drop=True).head(10)\
                                           .style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_0a11b91e_187b_11eb_80d4_02420a39e021row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_0a11b91e_187b_11eb_80d4_02420a39e021row1_col1 {
#             background-color:  #3aa03a;
#             color:  #000000;
#         }    #T_0a11b91e_187b_11eb_80d4_02420a39e021row2_col1 {
#             background-color:  #62b662;
#             color:  #000000;
#         }    #T_0a11b91e_187b_11eb_80d4_02420a39e021row3_col1 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_0a11b91e_187b_11eb_80d4_02420a39e021row4_col1 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }    #T_0a11b91e_187b_11eb_80d4_02420a39e021row5_col1 {
#             background-color:  #b1e2b1;
#             color:  #000000;
#         }    #T_0a11b91e_187b_11eb_80d4_02420a39e021row6_col1 {
#             background-color:  #cdf2cd;
#             color:  #000000;
# ...

# %% [markdown]
# Вывод по Санкт-Петербургу:
#
# Ключевые метрики в центре:
#
# 1) Расстояние до аэропорта <br>
# 2) Расстояние до центра <br>
# 3) Площадь квартиры <br>
# 4) Расстояние до ближайших водоёмов и их количество <br>
# 5) Расстояние до ближайшего парка и общее количество парков <br>
#
# Ключевые метрики по всему городу:
#
# 1) Жилая площадь <br>
# 2) Площадь кухни <br>
# 3) Количество комнат <br>
#
# Общий следующий - в центре люди хотят "кайфовать" - жить близко к достопримечательностям, гулять в парках\рядом с водоёмами, быстро доехать до аэропорта и полететь за границу, в общем - очень обеспеченные люди.
#  <br>
# Общие метрики по городу более приземлённые - это скорее обычные семьи которых больше волнует количество комнат, размер кухни, количество комнат (1 для родителей, 1 - для ребёнка).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# <b>Все отлично!👍:</b> Наверно, так и есть!😎
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Шаг 5. Общий вывод

# %% [markdown]
# Общий вывод сложу из промежуточных:
#
# Топ-5 по количеству объявлений:
#
# 1) Санкт-Петербург <br>
# 2) Поселок Мурино <br>
# 3) Поселок Шушары <br>
# 4) Всеволожск <br>
# 5) Паселок Парголово <br>
#
# Топ-3 по цене:
#
# 1) Санкт-Петербург <br>
# 2) Пушкин <br>
# 3) Поселок Шушары <br>
# 4) Паселок Парголово <br>
# 5) Поселок Мурино <br>
#
# Наибольшее количество объявлений о продаже - в Питере и пригороде, а заодно и цена там самая высокая. Интересным вариантом для приобритение жилья выглядит Всеволожск - предложений много, а цена - самая низкая (!)
#
#
# Вывод по Санкт-Петербургу:
#
# Ключевые метрики в центре:
#
# 1) Расстояние до аэропорта <br>
# 2) Расстояние до центра <br>
# 3) Площадь квартиры <br>
# 4) Расстояние до ближайших водоёмов и их количество <br>
# 5) Расстояние до ближайшего парка и общее количество парков <br>
#
# Ключевые метрики по всему городу:
#
# 1) Жилая площадь <br>
# 2) Площадь кухни <br>
# 3) Количество комнат <br>
#
# Общие метрики:
#
# 1) На 1-ом и последнем этажах квартиры дешевле <br>
# 2) В 2019 году цены на квартиры слегка подросли <br>
# 3) Самые дорогие квартиры - в Санкт-Петербурге (особенно - в центре), самые дешевые - во Всеволожске (данные по топ10 количеству размещенных объявлений) <br>
# 4) 2014 год содержит слишком мало данных, это выброс <br>
# 5) День недели\месяц\год на продажу не влияют <br>
# 6) Чем больше площадь квартиры - тем выше её цена (удивительно!) <br>
# 7) Средняя высота потолков ~2.7 метра <br>

# %% [markdown]
# ### <font color='orange'>Общий вывод по проекту</font>
# Сергей, спасибо за твой проект! Ты приложил много усилий, чтобы довести его до конца, многие задачи в рамках проекта у тебя получились, однако, есть несколько моментов, на которые стоит обратить внимание и скорректировать, чтобы твой проект стал еше лучше!  Обрати, пожалуйста, внимание на мои комментарии, они помогут тебе сориентироваться.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
# * На разных шагах проекта ты предлагал очень интересные, "программистские" решения. У тебя получились эффективные и довольно продвинутые функции. Крутая работа!
# * Ты активно работал с визуализацией: типы графиков выбраны корректно! Видно, что ты разбираешься в них и можешь использовать конкретные типы графиков под конкретную задачу.
# * Ты использовал сложные и любопытные методы для работы с данными, круто, что ты владеешь ими и можешь применять на практике.
#
# **На что следует обратить внимание🤔**:
# * Стоит уделить время оформлению проекта: важно добавить полноценное введение, не забывать о выводах на промежуточных шагах и комментариях/пояснениях к коду.
# * Формулирование выводов и комментарии, объяснения к коду - важная часть проекта. Представь себе такую картинку: если удалить весь твой код, твоя работа должна напоминать полноценный отчет. Т.е., быть состоятельной и полной без кода. Попробуй улучшить свой проект, опираясь на эту идею!
# * Стоит обратить больше внимания на оформление графиков: старайся оформлять визуализацию единообразно, писать названия осей и заголовки на русском языке. Помни, что графики - это важная часть проекта, зачастую, это его визитная карточка!
# * На некоторых шагах у тебя получились не совсем корректные выводы, стоит подумать, почему так получилось и попробовать скорректировать результат.
#
# **Желаю удачи и жду твой проект на повторной ревью**😉

# %% [markdown]
# ### <font color='blue'>Общий вывод по проекту: вторая итерация ревью</font>
# Сергей, спасибо, что прислал проект с внесенными коррективами. Здорово, что ты оставил пояснительные комметарии по ходу работы. Спешу тебе сообщить, что твоя проект принят, и ты можешь перейти на следующий этап.
# **Удачи на следующих принтах!🙌**

# %% [markdown]
# ### Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
