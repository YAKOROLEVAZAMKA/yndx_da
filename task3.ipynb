# %% [markdown]
# <font color='blue'>Привет! Поздравляю с уже третьим выполненным проектом. Кажется, намерения у тебя серьезные. Не все доходят до этого этапа, но те, кто дошли, уже не останавливаются 😉  Меня зовут Алексей Алексеев, я проверю твою работу и напишу свои комментарии. Они, в зависимости от результата проверки, будут в </font><font color='green'>зеленом (когда все отлично),</font> <font color='brown'>коричневом (когда можно лучше)</font><font color='blue'> или</font> <font color='red'>красном (когда нужно переделать, чтобы я принял работу). </font><font color='blue'> Ну и в синем будут просто советы и нейтральные комментарии.  Пожалуйста, не удаляй эти комментарии, они понадобятся нам для дальнейшей работы над проектом. Кстати, сразу предлагаю общаться на "ты".
# Наличие критичного или трех и более некритичных замечаний является поводом для отправки проекта на доработку. Некритичные замечания могут касаться нового материала, не освещенного в тренажере, но пожалуйста, не воспринимай их как мое необоснованное желание указать на твои ошибки. Изучать новый материал по ходу работы над проектом - это часть процесса обучения, на мой взгляд, очень эффективная. Так что не стесняйся задавать вопросы, если что-то не понятно. Наша общая цель - получить новые знания и навыки.
# А чтобы я точно не пропустил твои апдейты, желательно их также подсветить другим цветом, например, <font color='purple'>фиолетовым</font>.
#
# ---
# <font color='blue'>Апдейт после проверки: хороший проект, но давай еще немного поработаем.
#     Более подробно см. блок в конце.
#
# </font>

# %% [markdown]
# ## Задачи исследования
# ### 1. Осмотр и обработка данных
#
# - посмотрим наборы данных
# - сделаем предварительные выводы
# - поищем аномалии
# - найти и обработать пропуски
# - заменить некорректные типы данных
# - удалить дубликаты
# - привести данные к нужным типам
#
#
# ### 2. Подготовка данных
#
# Посчитайте для каждого пользователя:
#
# - количество сделанных звонков и израсходованных минут разговора по месяцам
# - количество отправленных сообщений по месяцам
# - объем израсходованного интернет-трафика по месяцам
# - помесячную выручку с каждого пользователя
#
# (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика, остаток умножьте на значение из тарифного плана)
#
# ### 3. Анализ данных
#
# - Опишите поведение клиентов оператора, исходя из выборки
# - Сколько минут разговора, сколько сообщений и какой объём интернет-трафика требуется пользователям каждого тарифа
# в месяц?
# - Посчитайте среднее количество, дисперсию и стандартное отклонение
# - Постройте гистограммы. Опишите распределения
#
#
# ### 4. Проверка гипотез
#
# - средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются
# - средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов
#
# Пороговое значение alpha задайте самостоятельно.
#
# Поясните:
#
# - как вы формулировали нулевую и альтернативную гипотезы
# - какой критерий использовали для проверки гипотез и почему
#
#
# ### 5. Результаты исследования
#
# - Общие выводы
# - Рекомендации
#
# ###  Этап 1. Опишем наборы данных, получим их, импортируем библиотеки
#
# #### Описание тарифов
#
# #### Тариф «Смарт»
#
#     Ежемесячная плата: 550 рублей
#     Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика
#
# #### Стоимость услуг сверх тарифного пакета:
#
#     минута разговора: 3 рубля («Мегалайн» всегда округляет вверх значения минут и мегабайтов. Если пользователь проговорил всего 1 секунду, в тарифе засчитывается целая минута.)
#     сообщение: 3 рубля
#     1 Гб интернет-трафика: 200 рублей
#
# #### Тариф «Ультра»
#
#     Ежемесячная плата: 1950 рублей
#     Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика
#
# #### Стоимость услуг сверх тарифного пакета:
#
#     минута разговора: 1 рубль
#     сообщение: 1 рубль
#     1 Гб интернет-трафика: 150 рублей
#
# ### Описание данных
#
# #### Путь к файлам:
#
#     /datasets/calls.csv
#     /datasets/internet.csv
#     /datasets/messages.csv
#     /datasets/tariffs.csv
#     /datasets/users.csv
#
# ### Описание таблиц
#
# #### Таблица users (информация о пользователях):
#
#     user_id — уникальный идентификатор пользователя
#     first_name — имя пользователя
#     last_name — фамилия пользователя
#     age — возраст пользователя (годы)
#     reg_date — дата подключения тарифа (день, месяц, год)
#     churn_date — дата прекращения пользования тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)
#     city — город проживания пользователя
#     tarif — название тарифного плана
#
# #### Таблица calls (информация о звонках):
#
#     id — уникальный номер звонка
#     call_date — дата звонка
#     duration — длительность звонка в минутах
#     user_id — идентификатор пользователя, сделавшего звонок
#
# #### Таблица messages (информация о сообщениях):
#
#     id — уникальный номер сообщения
#     message_date — дата сообщения
#     user_id — идентификатор пользователя, отправившего сообщение
#
# #### Таблица internet (информация об интернет-сессиях):
#
#     id — уникальный номер сессии
#     mb_used — объём потраченного за сессию интернет-трафика (в мегабайтах)
#     session_date — дата интернет-сессии
#     user_id — идентификатор пользователя
#
# #### Таблица tariffs (информация о тарифах):
#
#     tariff_name — название тарифа
#     rub_monthly_fee — ежемесячная абонентская плата в рублях
#     minutes_included — количество минут разговора в месяц, включённых в абонентскую плату
#     messages_included — количество сообщений в месяц, включённых в абонентскую плату
#     mb_per_month_included — объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)
#     rub_per_minute — стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со - 101 минуты будет взиматься плата)
#     rub_per_message — стоимость отправки сообщения сверх тарифного пакета
#     rub_per_gb — стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)

# %% [markdown]
# <font color='green'>Молодец, что в начале работы коротко описываешь наши данные и обрисовываешь цели. Хороший план - уже пол дела.
#    Кроме того, в таком виде работа смотрится цельно и её смогу оценить не только я, но и посторонний человек, в том числе потенциальный работодатель.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from datetime import datetime
from scipy import stats as st

# %%
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### 1. Осмотр и обработка данных

# %%
# Импорт данных
users = pd.read_csv('/datasets/users.csv') # абоненты
calls = pd.read_csv('/datasets/calls.csv') # звонки
messages = pd.read_csv('/datasets/messages.csv') # сообщения
internet = pd.read_csv('/datasets/internet.csv') # интернет-сессии
tariffs = pd.read_csv('/datasets/tariffs.csv') # тарифы

# %%
users.head()
# Out:
#    user_id  age churn_date         city first_name  last_name    reg_date  \
# 0     1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1     1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2     1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3     1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# 4     1004   68        NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# 4  ultra

# %%
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Полных дублей нет, это радует
# </div>

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# user_id       500 non-null int64
# age           500 non-null int64
# churn_date    38 non-null object
# city          500 non-null object
# first_name    500 non-null object
# last_name     500 non-null object
# reg_date      500 non-null object
# tariff        500 non-null object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %%
def convert_time(df, cols, time_format=r"%Y-%m-%d"):
    for col in cols:
        df[col] = pd.to_datetime(df[col], format=time_format)
        
convert_time(users, ['churn_date', 'reg_date'])

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Пишем функцию для проебразования строки в дату, применяем к дате подключения к тарифу и у дате завершения
# </div>

# %% [markdown]
# <font color=green>Классная идея упаковать рутинный процесс в функцию.

# %%
calls.head()
# Out:
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
# id           202607 non-null object
# call_date    202607 non-null object
# duration     202607 non-null float64
# user_id      202607 non-null int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB

# %%
calls.duplicated().sum()
# Out:
# 0

# %%
convert_time(calls, ['call_date'])
calls['id'] = calls['id'].astype(int)

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Дублей нет, преобразуем дату в дату, ид в число
# </div>

# %%
calls['duration'] = calls['duration'].apply(np.ceil).astype('int')

print('Звонков с нулевой длительностью -', calls.query('duration == 0').count()[0])
# Out:
# Звонков с нулевой длительностью - 39613

# %% [markdown]
# <font color='green'>Молодец, что не забываешь здесь не только округлить, но и сразу поменять тип. Это отличная привычка.

# %% [markdown]
# <font color='blue'>Интересный факт: похожий метод `math.ceil()` не только округляет, но и сразу приводит результат ц целочисленному типу.

# %%
calls = calls[calls['duration'] != 0].reset_index(drop=True)

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162994 entries, 0 to 162993
# Data columns (total 4 columns):
# id           162994 non-null int64
# call_date    162994 non-null datetime64[ns]
# duration     162994 non-null int64
# user_id      162994 non-null int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 5.0 MB

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Длительность звонков преобразовали в минуты с округлением вверх (по условиям тарифов оператора), звонки с длительностью 0 были удалены (т.к. это неотвеченные вызовы - звонок зафиксировался в БД, но абонент трубку не взял)
#
# </div>

# %% [markdown]
# <font color='green'>Согласен, в данных есть очень короткие разговоры, то есть нули это не округления, а что-то другое. Очень вероятно, что сброшенные/неотвеченные звонки, которые тарифицироваться не должны.

# %%
messages.head()
# Out:
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
# id              123036 non-null object
# message_date    123036 non-null object
# user_id         123036 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB

# %%
messages.duplicated().sum()
# Out:
# 0

# %%
convert_time(messages, ['message_date'])
messages['id'] = messages['id'].astype(int)

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Дублей нет, преобразование типов произвели
#
# </div>

# %%
internet.head()
# Out:
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1 1,052.81   2018-09-07     1000
# 2           2  1000_2 1,197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
# Unnamed: 0      149396 non-null int64
# id              149396 non-null object
# mb_used         149396 non-null float64
# session_date    149396 non-null object
# user_id         149396 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB

# %%
internet.drop(columns=['Unnamed: 0'], inplace=True)

# %%
internet.duplicated().sum()
# Out:
# 0

# %%
convert_time(internet, ['session_date'])
internet['id'] = internet['id'].astype(int)
internet['mb_used'] = internet['mb_used'].apply(np.ceil).astype(int)

# %%
internet = internet[internet['mb_used'] != 0].reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Дублей нет, преобразование типов произвели (мегабайты как и минуты округляются вверх), пустые сессии удалили, колонку <b>Unnamed: 0</b> удалили т.к. это человеческий фактор - дубликат колонки с индексом.
#
# </div>

# %% [markdown]
# <font color=blue>Метод `read_csv()` по умолчанию сам создает колонку с индексами. В данном случае, колонка с индексами у нас уже имеется, и мы можем сразу сделать её индексом датафрейма, указав `index_col=0`. Тогда ничего удалять не придется.

# %%
tariffs.head()
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %%
tariffs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
# messages_included        2 non-null int64
# mb_per_month_included    2 non-null int64
# minutes_included         2 non-null int64
# rub_monthly_fee          2 non-null int64
# rub_per_gb               2 non-null int64
# rub_per_message          2 non-null int64
# rub_per_minute           2 non-null int64
# tariff_name              2 non-null object
# dtypes: int64(7), object(1)
# memory usage: 256.0+ bytes

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Тут всё нормально ! (минуты это числа, а не строки, названия колонок адекватные, пропусков в данных нет и т.д.)
#
# </div>

# %% [markdown]
# <font color='green'>Данные загружены и изучены. Используются верные методы для получения общей информации о таблице. Успешно найдены и устранены имеющиеся проблемы.

# %% [markdown]
# ### Этап 2. Подготовка данных
#
# Посчитайте для каждого пользователя:
#
# - количество сделанных звонков и израсходованных минут разговора по месяцам
# - количество отправленных сообщений по месяцам
# - объем израсходованного интернет-трафика по месяцам
# - помесячную выручку с каждого пользователя
#
# (вычтите бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика, остаток умножьте на значение из тарифного плана)

# %% [markdown]
# ### Количество сделанных звонков и израсходованных минут разговора по месяцам

# %%
calls['month_name'] = calls['call_date'].dt.month_name()
calls['month'] = calls['call_date'].dt.month

# %%
users_calls = calls.groupby(['user_id', 'month', 'month_name'])\
                 .agg({'duration':'sum', 'id':'count'})\
                 .reset_index()\
                 .rename(columns={'duration':'month_calls_duration','id':'calls_total_in_month'})

users_calls.head()
# Out:
#    user_id  month month_name  month_calls_duration  calls_total_in_month
# 0     1000      5        May                   159                    17
# 1     1000      6       June                   172                    28
# 2     1000      7       July                   340                    41
# 3     1000      8     August                   408                    42
# 4     1000      9  September                   466                    46

# %%
users_calls.groupby(['month'])[['month_calls_duration']].sum().plot()

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Добавил № месяца + название месяца, сгруппировав по пользователям и месяцам подсчитал количество звонков для каждого пользователя по месяцам + общую продолжительность разговоров.
#
# В качестве маленького бонуса построил плохенький график (для себя, бизнесу не покажу!) суммарной продолжительности звонков по месяцам (года не учитываются) из которого видно что к концу года суммарная продолжительность резко возрастает. Хорошо этот или плохо, почему так произошло - пока что неизвестно, буду смотреть далее (если буду, вдруг оно не понадобится)
#
# </div>

# %% [markdown]
# <font color=green>Здорово,что ты так заботишься о бизнесе!

# %% [markdown]
# ### Количество отправленных сообщений по месяцам

# %%
messages['month_name'] = messages['message_date'].dt.month_name()
messages['month'] = messages['message_date'].dt.month

# %%
users_messages = messages.groupby(['user_id', 'month', 'month_name'])\
                        .agg({'id':'count'})\
                        .reset_index()\
                        .rename(columns={'id':'sms_total_in_month'})

users_messages.head()
# Out:
#    user_id  month month_name  sms_total_in_month
# 0     1000      5        May                  22
# 1     1000      6       June                  60
# 2     1000      7       July                  75
# 3     1000      8     August                  81
# 4     1000      9  September                  57

# %%
users_messages.groupby(['month'])[['sms_total_in_month']].sum().plot()

# %%
print(min(users['reg_date']))
print(max(users['reg_date']))
# Out:
# 2018-01-01 00:00:00
# 2018-12-31 00:00:00

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Добавил № месяца + название месяца, сгруппировав по пользователям и месяцам подсчитал количество sms для каждого пользователя по месяцам.
#
# Опять построил график, после которого определил дату регистрации 1-го пользователя в компании + последнего.
#
# В общем всё логично - скорее всего данный сотовый оператор открылся в начале 2018 года, а в кноце года решил проанализировать результаты своей работы - поэтому абонентов в начале 2018 года мало (поэтому и разговоров\смс мало), а ближе к середине-концу года абонентская база разрослась
#
# </div>

# %% [markdown]
# <font color=green>Здесь ты абсолютно прав.

# %% [markdown]
# ### небольшой оффтоп

# %%
users_test = users.copy()

users_test['month'] = users_test['reg_date'].dt.month
users_test['month_left'] = users_test['churn_date'].dt.month

users_join = users_test.groupby(['month'])[['user_id']].count().reset_index().rename(columns={'user_id':'total_users'})
users_left = users_test.groupby(['month_left'])[['user_id']].count().reset_index().rename(columns={'user_id':'left'})
users_total = users_join.merge(users_left, left_on='month', right_on='month_left', how='left')

def calculate_users(df, col_joins='total_users', col_discard='left', new_col='users_cohort'):
    df[new_col] = 0
    
    df[new_col][0] = df[col_joins][0]
    for i in range(1, df.shape[0]):
        df[new_col][i] = df[new_col][i-1] + df[col_joins][i]
        
    df[new_col] = df[new_col] - df[col_discard].fillna(0)    
        
calculate_users(users_total, new_col='users_cohort')

users_total
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#     month  total_users  month_left  left  users_cohort
# 0       1           43         nan   nan         43.00
# 1       2           39         nan   nan         82.00
# 2       3           32         nan   nan        114.00
# 3       4           53         nan   nan        167.00
# ...

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Предположение подтвердилось - в первом месяце было всего 43 абонента, на конец года - аж 484!
#
# Написал для этого функцию которая считает пользователей накопительным итогом, потом отнял абонентов которые отказались от услуг оператора
# </div>

# %% [markdown]
# <font color=blue>На будущее: есть классный метод `cumsum()`, считающий это автоматически:

# %%
#код ревьюера - можно удалить
users_test.groupby(['month'])['user_id'].count().cumsum()
# Out:
# month
# 1      43
# 2      82
# 3     114
# 4     167
# 5     208
# 6     248
# 7     292
# 8     342
# 9     377
# 10    422
# 11    464
# 12    500
# Name: user_id, dtype: int64

# %% [markdown]
# ### Объем израсходованного интернет-трафика по месяцам

# %%
internet['month_name'] = internet['session_date'].dt.month_name()
internet['month'] = internet['session_date'].dt.month

# %%
users_internet = internet.groupby(['user_id', 'month', 'month_name'])\
                         .agg({'mb_used':'sum'})\
                         .reset_index()\
                         .rename(columns={'mb_used':'mb_total_in_month'})

users_internet.head()
# Out:
#    user_id  month month_name  mb_total_in_month
# 0     1000      5        May               2256
# 1     1000      6       June              23257
# 2     1000      7       July              14016
# 3     1000      8     August              14070
# 4     1000      9  September              14581

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Подсчитал количество израсходованного абонентами трафика по месяцам
#
# </div>

# %% [markdown]
# <font color='green'>Итак, в таблицы успешно добавлена информация о месяцах. Данные агрегированы верно.

# %% [markdown]
# ### Месячная выручка с каждого пользователя

# %%
data = users.merge(users_calls, on=['user_id'], how='left')
data = data.merge(users_messages, on=['user_id', 'month', 'month_name'], how='left')
data = data.merge(users_internet, on=['user_id', 'month', 'month_name'], how='left')

data = data.merge(tariffs, left_on='tariff', right_on='tariff_name', how='left')
data.drop(columns=['tariff_name'], inplace=True)

# %% [markdown]
# <font color='brown'>Сравни количество строк в сводных таблицах до и после слияния. Похоже, мы потеряли какое-то количество записей (Немного, но кто знает, сколько мы можем потерять в следующий раз?).
#     Присоединяя одну таблицу к другой идущим по умолчанию методом `left` (`merge(how='left')`) мы теряем строки с теми ключами (в данном случае с теми `user_id`), которые есть в правой, но отсутствут в левой таблице.
#     Давай постараемся этого не допустить, так как в данном случае нам нужны все клиенты.

# %% [markdown]
# <font color='brown'>Также здесь имеет смысл взять из таблицы users только необходимые столбцы, чтобы не таскать за собой ненужные данные типа имени.

# %%
data
# Out:
#       user_id  age churn_date         city first_name  last_name   reg_date  \
# 0        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 2        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 3        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 4        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# ...       ...  ...        ...          ...        ...        ...        ...
# 3171     1498   68 2018-10-25  Владикавказ   Всеволод    Акимчин 2018-07-19
# 3172     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3173     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3174     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3175     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
#
# ...

# %%
data.isna().sum()
# Out:
# user_id                     0
# age                         0
# churn_date               2987
# city                        0
# first_name                  0
# last_name                   0
# reg_date                    0
# tariff                      0
# month                       8
# month_name                  8
# month_calls_duration        8
# calls_total_in_month        8
# sms_total_in_month        503
# mb_total_in_month          21
# messages_included           0
# mb_per_month_included       0
# minutes_included            0
# rub_monthly_fee             0
# rub_per_gb                  0
# rub_per_message             0
# rub_per_minute              0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['month_calls_duration'].fillna(0, inplace=True)
data['calls_total_in_month'].fillna(0, inplace=True)
data['sms_total_in_month'].fillna(0, inplace=True)
data['mb_total_in_month'].fillna(0, inplace=True)

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Промежуточный итог
#
#
# Я соединил все таблицы (расходы трафика, смс, сколько минут наговорил абонент) с users по user_id, далее заполнил нулями месяца в которых абонент не пользовался смс\интернет-трафиком\звонками.
#
# </div>

# %% [markdown]
# <font color='green'>Молодец, что учитываешь этот момент. Очень важно не удалять строки с этими пропусками, а заполнить нулями, мы же не хотим потерять пользователей, которые, например, не используют СМС.

# %%
def calculate_surpass(df, col, col_norm, col_final):
    df[col_final] = 0
    
    df[col_final] = df[col] - df[col_norm]
    df[col_final] = df[col_final].apply(lambda x: 0 if x < 0 else x)

# %%
calculate_surpass(data, 'month_calls_duration', 'minutes_included', 'minutes_overuse')
calculate_surpass(data, 'sms_total_in_month', 'messages_included', 'sms_overuse')
calculate_surpass(data, 'mb_total_in_month', 'mb_per_month_included', 'mb_overuse')

# %%
data
# Out:
#       user_id  age churn_date         city first_name  last_name   reg_date  \
# 0        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 2        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 3        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 4        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# ...       ...  ...        ...          ...        ...        ...        ...
# 3171     1498   68 2018-10-25  Владикавказ   Всеволод    Акимчин 2018-07-19
# 3172     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3173     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3174     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3175     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
#
# ...

# %%
data['total_payed'] = \
     data['rub_monthly_fee'] + \
     data['minutes_overuse'] * data['rub_per_minute'] + \
     data['sms_overuse'] * data['rub_per_message'] + \
     data['mb_overuse'] * (data['rub_per_gb'] / 1024)

data['overpay'] = data['total_payed'] - data['rub_monthly_fee']

# %%
data
# Out:
#       user_id  age churn_date         city first_name  last_name   reg_date  \
# 0        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 2        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 3        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 4        1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# ...       ...  ...        ...          ...        ...        ...        ...
# 3171     1498   68 2018-10-25  Владикавказ   Всеволод    Акимчин 2018-07-19
# 3172     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3173     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3174     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
# 3175     1499   35        NaT        Пермь     Гектор   Корнилов 2018-09-27
#
# ...

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Я объявил функцию которая считает количество Х сверх нормы (минуты, смс, интернет-трафик), далее посчитал сколько всего заплатил конкретный абонент за конкретный месяц, а так же сумму переплаты сверх тарифа.
#
# </div>

# %% [markdown]
# <font color='green'>Прибыль рассчитана верно. Молодец, что подтягиваешь тарифы напрямую из таблицы, а не используешь константы. При смене тарифов код переписывать не придется.
#  Получилась удобная компактная таблица, содержащая все необходимые данные.

# %% [markdown]
# ### 3. Анализ данных
#
# - Опишите поведение клиентов оператора, исходя из выборки
# - Сколько минут разговора, сколько сообщений и какой объём интернет-трафика требуется пользователям каждого тарифа
# в месяц?
# - Посчитайте среднее количество, дисперсию и стандартное отклонение
# - Постройте гистограммы. Опишите распределения

# %%
data['tariff'].value_counts()
# Out:
# smart    2223
# ultra     953
# Name: tariff, dtype: int64

# %%
data.boxplot('total_payed', by='tariff', figsize=(10,10)).set_ylim(0,7000)
plt.title('Оплата по тарифам', fontsize=25)
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 1.0, 'Оплата по тарифам')

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Из графика видно что абоненты тарифа <b>'ultra'</b> в общей массе платят фиксированную цену - 1950 руб. (ежемесячная плата) в то время как пользователи тарифа <b>'smart'</b> имеют разброс от ежемемячной платы 550 руб. до ~1600 руб, медианная плата - почти 1000 руб.!
#
# Абонентам тарифа <b>'smart'</b> стоит задуматься всё ли они делают правильно.
#
# </div>

# %%
data_analyze = data.groupby(['month', 
                             'tariff', 
                             'rub_per_message', 
                             'rub_per_minute', 
                             'rub_per_gb']).agg({'user_id': 'count',
                                            'total_payed': 'sum',
                                            'overpay': 'sum',
                                            'minutes_overuse': 'sum',
                                            'sms_overuse': 'sum',
                                            'mb_overuse': 'sum'
                                           }).reset_index().rename(columns={'user_id':'total_users'})

data_analyze['overpay_minutes'] = data_analyze['minutes_overuse'] * data_analyze['rub_per_minute']
data_analyze['overpay_sms'] = data_analyze['sms_overuse'] * data_analyze['rub_per_message']
data_analyze['overpay_mb'] = data_analyze['mb_overuse'] * (data_analyze['rub_per_gb'] / 1024)

data_analyze['month'] = data_analyze['month'].astype(int)


data_analyze['overpay_percent'] = round(data_analyze['overpay'] * 100 / data_analyze['total_payed'], 2)
data_analyze['overpay_minutes_percent'] = round(data_analyze['overpay_minutes'] * 100 / data_analyze['overpay'], 2)
data_analyze['overpay_sms_percent'] = round(data_analyze['overpay_sms'] * 100 / data_analyze['overpay'], 2)
data_analyze['overpay_mb_percent'] = round(data_analyze['overpay_mb'] * 100 / data_analyze['overpay'], 2)

data_analyze.fillna(0, inplace=True)

data_analyze = data_analyze[['month', 
                             'tariff', 
                             'total_users',
                             'total_payed',
                             'overpay',
                             'overpay_percent',
                             'overpay_minutes_percent', 
                             'overpay_sms_percent',
                             'overpay_mb_percent']]

# %%
data_analyze
# ЭТО ТАБЛИЦА АНАЛИЗА ПЕРЕПЛАТ В ПРОЦЕНТНОМ СООТНОШЕНИИ!
# Out:
#     month tariff  total_users  total_payed    overpay  overpay_percent  \
# 0       1  smart           33    23,336.91   5,186.91            22.23
# 1       1  ultra            9    17,550.00       0.00             0.00
# 2       2  smart           58    46,651.59  14,751.59            31.62
# 3       2  ultra           23    45,403.12     553.12             1.22
# 4       3  smart           77    86,115.45  43,765.45            50.82
# 5       3  ultra           37    74,154.35   2,004.35             2.70
# 6       4  smart          111   101,767.95  40,717.95            40.01
# 7       4  ultra           53   105,848.73   2,498.73             2.36
# 8       5  smart          141   161,715.99  84,165.99            52.05
# 9       5  ultra           64   131,832.71   7,032.71             5.33
# 10      6  smart          163   187,981.07  98,331.07            52.31
# 11      6  ultra           81   164,843.12   6,893.12             4.18
# ...

# %%
def median_payments(df, tarifflist, cols):
    for tariff in tarifflist:
        for col in cols:
            print(f"Медианное значение переплат по тарифу {tariff} = {round(df[df['tariff'] == tariff][col].median(), 2)}% за {cols[col]}")
        print('**********')
        
median_payments(data_analyze, 
                ['smart', 'ultra'], 
                {'overpay_minutes_percent': 'минуты', 
                 'overpay_sms_percent': 'sms',
                 'overpay_mb_percent': 'мегабайты'})
# Out:
# Медианное значение переплат по тарифу smart = 17.58% за минуты
# Медианное значение переплат по тарифу smart = 2.64% за sms
# Медианное значение переплат по тарифу smart = 80.03% за мегабайты
# **********
# Медианное значение переплат по тарифу ultra = 0.0% за минуты
# Медианное значение переплат по тарифу ultra = 0.0% за sms
# Медианное значение переплат по тарифу ultra = 100.0% за мегабайты
# **********

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Из таблицы видно что основные переплаты у абонентов тарифа <b>'smart'</b> - за интернет с большим отрывом, на втором месте - за минуты разговора сверх лимита, доля смс в переплатах - всего 2,5%.
#
# Абоненты тарифа <b>'ultra'</b> переплачивают только за интернет.
#
#
# Ps. описание функции - на вход получаем объект вида DataFrame, вторым аргументом идет список значений внутри столбцов из 3-его аргумента-словаря, в котором ключом является название столбца, а значением - его русскоязычная интерпретация. Далее по каждому тарифу выводим на экран медианное значение.
#
# </div>

# %% [markdown]
# <font color='green'>Отличная работа. Ты умеешь не только отвечать на поставленные вопросы, но и формулировать новые. Это очень ценно.

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 12)) # create 2x2 array of subplots


bxplt0_0 = data[data['tariff'] == 'ultra'].boxplot(column='total_payed', by='month', ax=axes[0,0])
bxplt0_0.set(xlabel='')
bxplt0_0.set(ylabel='Всего оплачено')
bxplt0_0.set(title='Тариф ultra по месяцам')


bxplt0_1 = data[data['tariff'] == 'ultra'].boxplot(column='calls_total_in_month', by='month', ax=axes[0,1])
bxplt0_1.set(xlabel='')
bxplt0_1.set(ylabel='Продолжительность разговора')
bxplt0_1.set(title='Тариф ultra по месяцам')


bxplt0_2 = data[data['tariff'] == 'ultra'].boxplot(column='mb_total_in_month', by='month', ax=axes[0,2])
bxplt0_2.set(xlabel='')
bxplt0_2.set(ylabel='Использовано трафика, мегабайт')
bxplt0_2.set(title='Тариф ultra по месяцам')
#
#

bxplt1_0 = data[data['tariff'] == 'smart'].boxplot(column='total_payed', by='month', ax=axes[1,0])
bxplt1_0.set(xlabel='')
bxplt1_0.set(ylabel='Всего оплачено')
bxplt1_0.set(title='Тариф smart по месяцам')

bxplt1_1 = data[data['tariff'] == 'smart'].boxplot(column='calls_total_in_month', by='month', ax=axes[1,1])
bxplt1_1.set(xlabel='')
bxplt1_1.set(ylabel='Продолжительность разговора')
bxplt1_1.set(title='Тариф smart по месяцам')


bxplt1_2 = data[data['tariff'] == 'smart'].boxplot(column='mb_total_in_month', by='month', ax=axes[1,2])
bxplt1_2.set(xlabel='')
bxplt1_2.set(ylabel='Использовано трафика, мегабайт')
bxplt1_2.set(title='Тариф smart по месяцам')

fig.suptitle('Анализ клиентского поведения', fontsize=26)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ...

# %%
data.groupby('tariff')\
    .agg({'calls_total_in_month':['median','mean','var','std']})\
    .style.format("{:.2f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_10057d06_2500_11eb_90c4_02420a391353" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4>calls_total_in_month</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >median</th>        <th class="col_heading level1 col1" >mean</th>        <th class="col_heading level1 col2" >var</th>        <th class="col_heading level1 col3" >std</th>    </tr>    <tr>        <th class="index_name level0" >tariff</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_10057d06_2500_11eb_90c4_02420a391353level0_row0" class="row_heading level0 row0" >smart</th>
#                         <td id="T_10057d06_2500_11eb_90c4_02420a391353row0_col0" class="data row0 col0" >48.00</td>
# ...

# %%
data.groupby('tariff')\
    .agg({'sms_total_in_month':['median','mean','var','std']})\
    .style.format("{:.2f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_10093d42_2500_11eb_90c4_02420a391353" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4>sms_total_in_month</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >median</th>        <th class="col_heading level1 col1" >mean</th>        <th class="col_heading level1 col2" >var</th>        <th class="col_heading level1 col3" >std</th>    </tr>    <tr>        <th class="index_name level0" >tariff</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_10093d42_2500_11eb_90c4_02420a391353level0_row0" class="row_heading level0 row0" >smart</th>
#                         <td id="T_10093d42_2500_11eb_90c4_02420a391353row0_col0" class="data row0 col0" >28.00</td>
# ...

# %%
data.groupby('tariff')\
    .agg({'mb_total_in_month':['median','mean','var','std']})\
    .style.format("{:.2f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_100c0464_2500_11eb_90c4_02420a391353" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4>mb_total_in_month</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >median</th>        <th class="col_heading level1 col1" >mean</th>        <th class="col_heading level1 col2" >var</th>        <th class="col_heading level1 col3" >std</th>    </tr>    <tr>        <th class="index_name level0" >tariff</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_100c0464_2500_11eb_90c4_02420a391353level0_row0" class="row_heading level0 row0" >smart</th>
#                         <td id="T_100c0464_2500_11eb_90c4_02420a391353row0_col0" class="data row0 col0" >16500.00</td>
# ...

# %% [markdown]
# <font color=green>Стат. параметры успешно рассчитаны и наглядно и компактно выведены.

# %%
data.groupby(['tariff'])[['user_id']].count().reset_index()
# Out:
#   tariff  user_id
# 0  smart     2223
# 1  ultra      953

# %%
total_ultra = data.query('tariff == "ultra"')['user_id'].count() 
overusers_ultra = data.query('tariff == "ultra" and mb_total_in_month > 30720')['user_id'].count()
round(overusers_ultra / total_ultra * 100, 2)
# Out:
# 13.43

# %%
total_smart = data.query('tariff == "smart"')['user_id'].count() 
overusers_smart = data.query('tariff == "smart" and overpay > 0')['user_id'].count()
round(overusers_smart / total_smart * 100, 2)
# Out:
# 74.67

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Выводы:
#
# 1) Смс наименее популярный канал общения среди абонентов - на тарифе  <b>'ultra'</b> переплат нет вовсе, в то время как на тарифе <b>'smart'</b> медианное значение переплат всего лишь около 2.5%. В среднем абоненты используют около 30-40 смс-ок в месяц (что меньше 50 включенных смс в тариф <b>'smart'</b> и очень сильно меньше 1000 на тарифе <b>'ultra'</b>)
#
# 2) Голосовое общение так же теряет популярность - средняя продолжительность общения 50 минут в месяц на тарифе <b>'smart'</b> и 60 минут на тарифе <b>'ultra'</b>. К слову, количество ежемесячных минут - 500 и 3000 соответственно. Как и в случае с смс-сообщениями - абсолютное большинство пользователей не использует предоставленный лимит.
#
# 3) Самое сладкое - интернет-трафик. Основная масса переплат - именно за него (100% у тарифа <b>'ultra'</b> и 80% у тарифа <b>'smart'</b>). В среднем абоненты тарифа <b>'smart'</b> используют 16 Гб в месяц - это на 10% больше чем включенный в тарифный план трафик. Абоненты тарифа <b>'ultra'</b> в среднеи используют 19 Гб трафика - это меньшие чем тарифные 30 Гб, но встречаются индивидуумы которые расходут 40+ Гб в месяц.
#
# <h2> Предварительный итог</h2>
#
# В первом и втором месяцах абонентская база была еще слишком мала, данные разнятся, однако начиная с 3-его месяца данные "устаканиваются" () и держатся примерно на одном и том же уровне до конца года (см. <b>Анализ клиентского поведения</b>).
#
#
# Абоненты тарифа <b>'ultra'</b> за ~2000 рублей в месяц имеют всё необходимое - перерасхода минут\смс нет вообще, за интернет переплачивает малая часть абонентов - всего 13%.
#
# Абоненты тарифа <b>'smart'</b> в основной массе платят двойную абонентскую плату (из-за перерасхода интернет-трафика), но в тоже время это в 2 раза меншь чем абонентская плата тарифа <b>'ultra'</b> - всего лишь 1000 рублей вместо 2000 рублей. Голосовое общение \ смс почти на том же уровне что и в более дорогом тарифе - 50 минут против 60, 30 сообщений против примерно ~42-ух соответственно, и первое и второе ниже включенного в тарифные планы.
#
# </div>

# %% [markdown]
# <font color=green>Что же, анализ проделан великолепный. Он получился на порядок глубже ожидаемого. Очень подробно описано поведение пользователей: сколько им нужно трафика/минут/сообщений в месяц, хватает ли им, часто ли они переплачивают и за что конктерно. Даже нечего добавить.

# %%
data[data['tariff'] == 'ultra']['calls_total_in_month'].plot(kind='hist', bins=12)
plt.title('Тариф Ultra, продолжительность разговоров в месяц')
# Out:
# Text(0.5, 1.0, 'Тариф Ultra, продолжительность разговоров в месяц')

# %% [markdown]
# <div class="alert alert-info">
#     <h2> P.S.2:</h2>
#
# Гистограммы строить умею, пример выше.
#
# Боксплоты показались мне более уместными т.к. я смог визуально оценить клиентское поведение по месяцам и прийти к соответствующим выводам (первые 2 месяца, а так же 4-й в ряде случаев - нестабильные, 3 и 5+ месяца показывают стабильность во всём), медианную ежемесячную плату по тарифам и т.д.
#
# В то время как на гистограммах я бы увидел только "следствие" без "причины".
#
# </div>

# %% [markdown]
# <font color=green>Хороший постскриптум, бе него я бы обязательно придрялся 😉 Но с такой аргументацией не могу не согласиться - ты проделал замечательный анализ на своих графиках.

# %% [markdown]
# ### 4. Проверка гипотез
#
# - средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются
# - средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов
#
# Пороговое значение alpha задайте самостоятельно.
#
# Поясните:
#
# - как вы формулировали нулевую и альтернативную гипотезы
# - какой критерий использовали для проверки гипотез и почему

# %%
ultra = data[data['tariff'] == 'ultra']
smart = data[data['tariff'] == 'smart']

# %%
def drop_anomalies(df, col):
    q1 = df[col].quantile(0.25)                 
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    iqr_test = (df[col] >= (q1 - 1.5 * iqr)) & (df[col] <= (q3 + 1.5 * iqr))

    return df.loc[iqr_test][col]

# %%
ultra = drop_anomalies(ultra, 'total_payed')

smart = drop_anomalies(smart, 'total_payed')

# %% [markdown]
# <font color=blue>Здесь необязательно избавляться от выбросов - они отнюдь не экстремальны. К тому же, в некоторых индустриях (например в условно-бесплатных видеоиграх) бОльшая часть прибыли приходит именно от 5%-10% платящих пользователей, поэтому мы просто не можем их игнорировать в исследовании.

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Для сравнения средней выручки я написал функцию удаления значений из данных которые находятся вне интерквартильного размаха и в результате возвращает объет Series для дальнейшего статистического анализа
#
#
# <b>Сформулируем гипотезы:</b>
#
# <b>H0</b>: выручка пользователей тарифов <b>'ultra'</b> и <b>'smart'</b> не различается<br>
# <b>H1</b>: выручка пользователей тарифов <b>'ultra'</b> и <b>'smart'</b> различается
#
#
# </div>

# %%
alpha = 0.05

results = st.ttest_ind(ultra, smart)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 9.102163861576608e-195
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Разумееся нулевая гипотеза была отвергнута - из анализа выше мы знаем что в 87% пользователей тарифов <b>'ultra'</b> не переплачивают в принципе и довольствуются базовым пакетом услуг, в то время как 75% абонентов тарифа <b>'smart'</b> ежемесячно переплачивают
#
#
#
#
# <b>Гипотеза о равенстве средних двух генеральных совокупностей №2</b>
#
#
#
# <b>H0</b>: средняя выручка пользователей из Москвы не отличается от выручки пользователей из других регионов<br>
# <b>H1</b>: средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов
#
#
#
# </div>

# %% [markdown]
# <font color=blue>По итогам первой гипотезы: пользователи 'ultra' не переплачивают, но все же платят они больше. (Из анализа выше).

# %% [markdown]
# <font color='green'>В целом же без вопросов, гипотезы сформулированы и проверены верно. Выборки для проверки построены верно. Методы выбраны верно. Ты отлично понимаешь принцип проверки статистических гипотез.

# %%
data['city'].unique()
# Out:
# array(['Краснодар', 'Москва', 'Стерлитамак', 'Новокузнецк',
#        'Набережные Челны', 'Ульяновск', 'Челябинск', 'Пермь', 'Тюмень',
#        'Самара', 'Санкт-Петербург', 'Иваново', 'Чебоксары', 'Омск', 'Уфа',
#        'Томск', 'Чита', 'Мурманск', 'Петрозаводск', 'Тверь',
#        'Екатеринбург', 'Махачкала', 'Вологда', 'Череповец', 'Ярославль',
#        'Сочи', 'Хабаровск', 'Ставрополь', 'Рязань', 'Улан-Удэ', 'Тула',
#        'Саратов', 'Ростов-на-Дону', 'Казань', 'Иркутск', 'Курск',
#        'Калуга', 'Якутск', 'Астрахань', 'Химки', 'Владикавказ',
#        'Волгоград', 'Саранск', 'Ижевск', 'Новосибирск', 'Брянск',
#        'Тольятти', 'Нижний Тагил', 'Орёл', 'Белгород', 'Воронеж',
#        'Волжский', 'Курган', 'Барнаул', 'Красноярск', 'Архангельск',
#        'Липецк', 'Кемерово', 'Киров', 'Сургут', 'Пенза', 'Магнитогорск',
#        'Нижний Новгород', 'Кострома', 'Владивосток', 'Тамбов', 'Балашиха',
#        'Севастополь', 'Калининград', 'Оренбург', 'Смоленск',
# ...

# %%
data['city_type'] = data['city'].apply(lambda x: x if x == 'Москва' else 'Другой регион')

# %%
moscow = data[data['city_type'] == 'Москва']
region = data[data['city_type'] == 'Другой регион']

moscow = drop_anomalies(moscow, 'total_payed')
region = drop_anomalies(region, 'total_payed')

alpha_mr = 0.05 # mr - Moscow\region

results_mr = st.ttest_ind(moscow, region)

print('p-значение:', results_mr.pvalue)

if (results_mr.pvalue < alpha_mr):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.21505745632648549
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-info">
#     <h2> Комментарий учащегося</h2>
#
# Как видно из результатов выше (делал все аналогично расчета выручки - удалил выбросы-очистил выборку, провел t-тест двух независимых выборок) выручка по абонентам из Москвы не отличается от выручки по абонентам из других регионов.
#
# </div>

# %% [markdown]
# <font color='green'>Со второй гипотезой также все отлично.

# %% [markdown]
# ### 5. Результаты исследования
#
# - Пользователи тарифа <b>'ultra'</b> в основном довольствуются базовым пакетом услуг, в то время как абоненты тарифа <b>'smart'</b> регулярно переплачивают - в основном за доп. интернет-трафик.
#
# - Смс и голосовое общение отошло на второй план - больше всего пользователи общаются через интернет (вероянто через мессенджеры и соц. сети)
#
# - Среднее количество израсходованных минут в месяц (по обоим тарифам) - от 50 до 60
#
# - Среднее количество израсходованных смс в месяц (по обоим тарифам) - от 30 до 42
#
# - Средний израсходованный интернет-трафик за месяц (по обоим тарифам) - 16-19 Гб в месяц
#
#
#
# Итого для среднестатического пользователя лучше воспользоваться более дешевым тарифом <b>'smart'</b> и платить около 1000 рублей в месяц чем платить 2000 рублей за <b>'ultra'</b>.
#
#
# Сотовый оператор (если говорить сухим статистическим языком) - <b>молодец</b> (без сарказма). Гибкого тарифа (без смс и звонков, но с большим количеством интернет-трафика) нет и пользователи вынуждены либо переплачивать либо пользоваться дорогим тарифом - от этого выручка оператора явно выше.
#
# В доказательство этого - за год абонентская база с 0 пользователей выросла до 500 (при этом отказались от услуг оператор всего лишь 38, а это менее 10%).
#
#
# Если доля уходящих абонентов будет возрастать (не все люди любят явно переплачивать) то вариантом будет создать тариф <b>'ИНТЕРНЕТИИЩЕЕЕ'</b> - c 20 Гб интернета (основной массе пользователей этого будет хватать за глаза), 50 минутами и 10 смс за 999 рублей!
#
# Объяснение:
# - пользователи тарифа <b>'smart'</b> перейдут на этот тариф и будут платить столько же сколько платят сейчас с переплатой
# - пользователи тарифа <b>'ultra'</b> перейдут на этот тариф и будут доплачивать за минуты и смс сверх тарифа
# - стоимость минут и смс сверх тарифа должна быть высокой (в районе 30 рублей за минуту\смс) т.к. средняя продолжительность разговора тарифа <b>'ultra'</b> - 60 минут, 10 * 30 = 300, смс - 40 - 10 = 30 * 30 = 900, итого - 999 + 1200 = ~2200, +250 рублей к выручке. Почему так дорого? Это уже работа маркетологов.

# %% [markdown]
# <font color=green>Вывод, можно сказать, показательный: подведен подробный итог всей работы, проведено сравнение тарифов, даны обоснованные экспертные советы для бизнеса 👏

# %% [markdown]
# <font color='green'>К оформлению работы претензий нет. Соблюдена структура проекта, полноценно используется разметка для комментариев. Код чистый, выводы понятные.

# %% [markdown]
# <font color='blue'>Итак, очень хорошая работа, ты показываешь отличные знания нового материала и умение их применять. Ты уверенно объединяешь и аггрегируешь данные из разных датафреймов, считаешь статистические параметры и работаешь с гипотезами. Также строишь хорошие графики. У тебя верные и четкие выводы.
#     Не люблю принимать работы с первого раза, но пара незначительных замечаний явно не повод отправлять проект на доработку. Уверен, с методом объединения `outer` ты разберешься самостоятельно. Так держать! Успехов в сборном проекте.
